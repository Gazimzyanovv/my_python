# %%
import pandas as pd
import json

# %%
with open('файл json.txt', encoding="utf8") as data:
          file=data.readlines()

# %%
l=[json.loads(i) for i in file if "index" not in i]

# %%
df1=pd.DataFrame(l)
df1.head(5)
# Out:
#                                              vacancy   company creation_date  \
# 0   Начинающий специалист по залоговому кредитованию  Тинькофф    2019-01-15
# 1                       Начинающий специалист в банк  Тинькофф    2019-01-15
# 2  Менеджер по работе с корпоративными клиентами ...  Тинькофф    2019-01-15
# 3            Менеджер по привлечению юридических лиц  Тинькофф    2019-01-15
# 4            Менеджер по привлечению юридических лиц  Тинькофф    2019-01-15
#
#      region                     income    experience   employment_type  \
# 0    Москва             от 55 000 руб.  не требуется  Полная занятость
# 1    Москва             от 50 000 руб.  не требуется  Полная занятость
# 2    Москва  от 50 000 до 150 000 руб.      1–3 года  Полная занятость
# 3   Коломна             от 80 000 руб.  не требуется  Полная занятость
# 4  Одинцово             от 80 000 руб.  не требуется  Полная занятость
#
#                                               duties  \
# ...

# %%
List=[]
for i in range(0,len(df1)):
    List.append({"Вакансия":df1.vacancy[i],"Зарплата":df1.income[i],"Регион":df1.region[i]})

# %%
df2 = pd.DataFrame(List)
df2.head(30)
# Out:
#                                              Вакансия  \
# 0    Начинающий специалист по залоговому кредитованию
# 1                        Начинающий специалист в банк
# 2   Менеджер по работе с корпоративными клиентами ...
# 3             Менеджер по привлечению юридических лиц
# 4             Менеджер по привлечению юридических лиц
# 5             Менеджер по привлечению юридических лиц
# 6             Менеджер по привлечению юридических лиц
# 7             Менеджер по привлечению юридических лиц
# 8             Менеджер по привлечению юридических лиц
# 9             Менеджер по привлечению юридических лиц
# 10            Менеджер по привлечению юридических лиц
# 11            Менеджер по привлечению юридических лиц
# 12            Менеджер по привлечению юридических лиц
# 13            Менеджер по привлечению юридических лиц
# 14            Менеджер по привлечению юридических лиц
# 15            Менеджер по привлечению юридических лиц
# ...
